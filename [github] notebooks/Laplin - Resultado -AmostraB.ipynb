# %%
import Laplin as lp
import numpy as np
import matplotlib.pyplot as plt

# %%
file = 'Amostra B/amostraB_tratada.txt'
cpmg = lp.ExpData()
cpmg.loadFile(file,1,2)

# %%
for i in range(len(cpmg.x)):
    cpmg.x[i] *= 1e-3

# %%
plt.plot(cpmg.x,cpmg.yn,'c-')
plt.xlabel('direct time [s]')
plt.ylabel('amplitude with noise')
plt.grid(True)
plt.legend(['Amostra B'],loc=0)
plt.savefig('Decay_B.png',dpi=300)

# %%
reg = lp.InvLaplace(cpmg, 0)
reg.genX(1e-4,1e0,100)
reg.genY([1,0,1], 0, 'nn0')

N = max(reg.Y)
for j in range(len(reg.Y)):
    reg.Y[j] /= N

for k in range(len(reg.Y)-1):
    if reg.Y[k-1] < reg.Y[k] and reg.Y[k+1] < reg.Y[k] and reg.Y[k] > 0.2:
        print 'O pico de intensidade ocorre para T2 =', reg.X[k]/1e-3, '+/-', (reg.X[k+1] - reg.X[k-1])/2e-3, 'ms.'

print 'Amostra B, com intervalo de', len(reg.X), 'pontos entre 1e-4 e 1e0 do espaço inverso.'

reg.plotData()
# Out:
# O pico de intensidade ocorre para T2 = 117.681195244 +/- 10.9641221502 ms.
# Amostra B, com intervalo de 100 pontos entre 1e-4 e 1e0 do espaço inverso.

# %%
plt.plot(reg.X,reg.Y,'c-')
plt.xlabel('inverse time [s]')
plt.ylabel('amplitude')
plt.xscale('log')
plt.grid(True)
plt.legend(['Amostra B'], loc=0)
plt.text(4e-3, 0.95, 'T2 = 120 +/- 10 ms')
plt.savefig('B_inverse.png', dpi=300)
