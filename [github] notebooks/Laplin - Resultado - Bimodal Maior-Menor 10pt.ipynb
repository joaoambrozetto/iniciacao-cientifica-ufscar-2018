# %%
### ARQUIVO FINALIZADO ###

# %%
### ROTINA DE TRABALHO: ###

# *Cada arquivo contém somente um dado número de pontos (N = 500; 100; 50; 10);
# *Uma distribuição simulada por arquivo, sendo elas: Bimodal Iguais, Bimodal Maior/Menor e Bimodal Menor/Maior;
# *Cada arquivo com 10 valores de SNR, sendo eles: 100.000, 10.000, 1.000, 100, 10, 1;
# *Serão aplicadas as penalizações 'n' (norma), 'g' (gradiente) e 'c' (curvatura) e também a não-negatividade 'nn0';
# *Segundo a lógica proposta, serão 12 arquivos como este, contendo 72 decaimentos analisados no total;

# mg1 = [[1e-3,0.3,1],[1e-1,0.3,1]]
# mg2 = [[1e-3,0.3,1],[1e-1,0.3,0.5]]
# mg3 = [[1e-3,0.3,0.5],[1e-1,0.3,1]]
# Xi = 1e-4; Xf = 1e0
# Manter a densidade de pontos em 1 pt/ms ou 1000 pts/s

#ARQUIVO 10 PTS

# %%
import Laplin as lp
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

# %%
def FindOpt(ni,nf,Ns,gi,gf,Gs,ci,cf,Cs,reg):
    #Ajuste Grosso
    Bn = (nf/ni)**(1.0/(Ns-1))
    Bg = (gf/gi)**(1.0/(Gs-1))
    Bc = (cf/ci)**(1.0/(Cs-1))
    Min = 1e10
    for i in range(Ns):
        n=ni*Bn**i
        print "Laço ",n," da varredura em Ns."
        for j in range(Gs):
            g=gi*Bg**j
            for k in range(Cs):
                c=ci*Bc**k
                reg.genY([n,g,c],0,'nn0')
                RMS = lp.rmsDiff(sim.Y,reg.Y)
                if RMS < Min:
                    Min = RMS
                    PRes = [RMS,n,g,c]
                    print 'Última otimização do ajuste grosso: ',PRes
    #Ajuste Fino
    Bn = Bn**(1.0/(Ns-1))
    Bg = Bg**(1.0/(Gs-1))
    Bc = Bc**(1.0/(Cs-1))
    for i in range(Ns):
        n=PRes[1]*Bn**i
        print "Laço ",n," da varredura em N."
        for j in range(Gs):
            g=PRes[2]*Bg**j
            for k in range(Cs):
                c=PRes[3]*Bc**k
                reg.genY([n,g,c],0,'nn0')
                RMS = lp.rmsDiff(sim.Y,reg.Y)
                if RMS < Min:
                    Min = RMS
                    PRes = [RMS,n,g,c]
                    print 'Última otimização do ajuste fino: ',PRes
    return PRes

# %%
mg = [[5e-3,0.7,1],[5e-2,0.5,0.5]] #[tc, dt, amp]
sim = lp.MultiGauss(mg)
sim.genData(1e-4,1e0,10) #[Xi, Xf, N]
#sim.plotData()

plt.plot(sim.X,sim.Y)
#plt.xlabel('inverse time [s]')
#plt.ylabel('amplitude')
plt.xscale('log')
#plt.grid(True)
#plt.legend(['Dist. Simulada'],loc=0)
plt.savefig('Tabela_Mm_10pt.png',dpi=300)

# %%
mg = [[5e-3,0.7,1],[5e-2,0.5,0.5]] #[tc, dt, amp]
sim = lp.MultiGauss(mg)
sim.genData(1e-4,1e0,10) #[Xi, Xf, N]
#sim.plotData()

plt.plot(sim.X,sim.Y)
plt.xlabel('inverse time [s]')
plt.ylabel('amplitude')
plt.xscale('log')
plt.grid(True)
plt.legend(['Dist. Simulada'],loc=0)
plt.savefig('Sim_Dist_Mm_10pt.png',dpi=300)

# %%
# SNR = 100.000

sig1 = lp.NMRDecay(sim, 'cpmg') #'cpmg'/'invrec'
sig1.genX(1e-4,2,2000) #xi, xf, N
sig1.genY()
sig1.addGaussNoise(1e5)
#sig1.plotData()

plt.plot(sig1.x,sig1.yn)
plt.xlabel('direct time [s]')
plt.ylabel('amplitude with noise')
plt.grid(True)
plt.legend(['Dec. Simulado'],loc=0)
plt.savefig('Sim_Decay_1e5_Mm_10pt.png',dpi=300)

# %%
reg1 = lp.InvLaplace(sig1, 0) #0=cpmg/1=invrec
reg1.genX(1e-4,1e0,10) #Xi, Xf, N

Opt1 = FindOpt(1e-8,2,10,1e-8,2,10,1e-8,2,10,reg1)
print Opt1
# Out:
# Laço  1e-08  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.0011993194921280927, 1e-08, 1e-08, 1e-08]
# Última otimização do ajuste grosso:  [0.0011899224579890585, 1e-08, 1e-08, 8.362510309503733e-08]
# Última otimização do ajuste grosso:  [0.0011129221914460159, 1e-08, 1e-08, 6.993157867655623e-07]
# Última otimização do ajuste grosso:  [0.000672548174519219, 1e-08, 1e-08, 5.848035476425729e-06]
# Última otimização do ajuste grosso:  [0.0006721419624157361, 1e-08, 8.362510309503733e-08, 5.848035476425729e-06]
# Última otimização do ajuste grosso:  [0.0006688705813263488, 1e-08, 6.993157867655623e-07, 5.848035476425729e-06]
# Última otimização do ajuste grosso:  [0.0006506206255304516, 1e-08, 5.848035476425729e-06, 5.848035476425729e-06]
# Laço  8.3625103095e-08  da varredura em Ns.
# Laço  6.99315786766e-07  da varredura em Ns.
# Laço  5.84803547643e-06  da varredura em Ns.
# Laço  4.8904256962e-05  da varredura em Ns.
# Laço  0.000408962353023  da varredura em Ns.
# Laço  0.00341995189335  da varredura em Ns.
# Laço  0.0285993829662  da varredura em Ns.
# Laço  0.2391626349  da varredura em Ns.
# Laço  2.0  da varredura em Ns.
# Laço  1e-08  da varredura em N.
# Última otimização do ajuste fino:  [0.0006484145542199779, 1e-08, 7.404433727112819e-06, 5.848035476425729e-06]
# Laço  1.26614035721e-08  da varredura em N.
# Última otimização do ajuste fino:  [0.0006478738081336139, 1.2661403572124612e-08, 9.37505236420262e-06, 5.848035476425729e-06]
# Laço  2.02976404592e-08  da varredura em N.
# Laço  2.56996617415e-08  da varredura em N.
# Laço  3.25393788977e-08  da varredura em N.
# Laço  4.1199420821e-08  da varredura em N.
# Laço  5.21642493952e-08  da varredura em N.
# Laço  6.6047261363e-08  da varredura em N.
# Laço  8.3625103095e-08  da varredura em N.
# Laço  1.05881117905e-07  da varredura em N.
# [0.0006478738081336139, 1.2661403572124612e-08, 9.37505236420262e-06, 5.848035476425729e-06]

# %%
reg1 = lp.InvLaplace(sig1, 0) #0=cpmg/1=invrec
reg1.genX(1e-4,1e0,10) #Xi, Xf, N
reg1.genY([1.2661403572124612e-08, 9.37505236420262e-06, 5.848035476425729e-06], 0, 'nn0') #[N,G,C], 0=noTSVD/1=TSVD, '0'/'nn0'/'nnx'/'x'
#sim.plotData()
#reg1.plotData()
#plt.show()
#print 'Desvio quadrático médio:', lp.rmsDiff(sim.Y, reg1.Y) #utilizar 2 ou 3 algarismos significativos

plt.plot(sim.X,sim.Y)
plt.plot(reg1.X,reg1.Y)
plt.xlabel('inverse time [s]')
plt.ylabel('amplitude')
plt.xscale('log')
plt.grid(True)
plt.legend(['Dist. Simulada','Dist. TLI'],loc=0)
plt.text(0.002,0,'Desvio RMS: 0.0006')
plt.savefig('Sim_Comp_1e5_Mm_10pt.png',dpi=300)

# %%
# SNR = 10.000

sig2 = lp.NMRDecay(sim, 'cpmg') #'cpmg'/'invrec'
sig2.genX(1e-4,2,2000) #xi, xf, N
sig2.genY()
sig2.addGaussNoise(1e4)
#sig2.plotData()

plt.plot(sig2.x,sig2.yn)
plt.xlabel('direct time [s]')
plt.ylabel('amplitude with noise')
plt.grid(True)
plt.legend(['Dec. Simulado'],loc=0)
plt.savefig('Sim_Decay_1e4_Mm_10pt.png',dpi=300)

# %%
reg2 = lp.InvLaplace(sig2, 0) #0=cpmg/1=invrec
reg2.genX(1e-4,1e0,10) #Xi, Xf, N

Opt2 = FindOpt(1e-8,2,10,1e-8,2,10,1e-8,2,10,reg2)
print Opt2
# Out:
# Laço  1e-08  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.0029562566741065453, 1e-08, 1e-08, 1e-08]
# Última otimização do ajuste grosso:  [0.002950425807302354, 1e-08, 1e-08, 8.362510309503733e-08]
# Última otimização do ajuste grosso:  [0.0029018771848964044, 1e-08, 1e-08, 6.993157867655623e-07]
# Última otimização do ajuste grosso:  [0.002512747769614637, 1e-08, 1e-08, 5.848035476425729e-06]
# Última otimização do ajuste grosso:  [0.002395293083468448, 1e-08, 1e-08, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.0021406841420608335, 1e-08, 4.8904256961953734e-05, 1e-08]
# Última otimização do ajuste grosso:  [0.0021363220983503122, 1e-08, 4.8904256961953734e-05, 8.362510309503733e-08]
# Última otimização do ajuste grosso:  [0.002100348307041636, 1e-08, 4.8904256961953734e-05, 6.993157867655623e-07]
# Última otimização do ajuste grosso:  [0.001840134336272802, 1e-08, 4.8904256961953734e-05, 5.848035476425729e-06]
# Laço  8.3625103095e-08  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.0018400346869250372, 8.362510309503733e-08, 4.8904256961953734e-05, 5.848035476425729e-06]
# Laço  6.99315786766e-07  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.0018392041168419835, 6.993157867655623e-07, 4.8904256961953734e-05, 5.848035476425729e-06]
# Laço  5.84803547643e-06  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.0018324504256130927, 5.848035476425729e-06, 4.8904256961953734e-05, 5.848035476425729e-06]
# Laço  4.8904256962e-05  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.001789732678494925, 4.8904256961953734e-05, 4.8904256961953734e-05, 5.848035476425729e-06]
# Laço  0.000408962353023  da varredura em Ns.
# Laço  0.00341995189335  da varredura em Ns.
# Laço  0.0285993829662  da varredura em Ns.
# Laço  0.2391626349  da varredura em Ns.
# Laço  2.0  da varredura em Ns.
# Laço  4.8904256962e-05  da varredura em N.
# Última otimização do ajuste fino:  [0.0017453989551304307, 4.8904256961953734e-05, 4.8904256961953734e-05, 7.404433727112819e-06]
# Última otimização do ajuste fino:  [0.0016763709148604306, 4.8904256961953734e-05, 4.8904256961953734e-05, 1.1870132149297034e-05]
# Laço  6.1919653379e-05  da varredura em N.
# Laço  7.83989720478e-05  da varredura em N.
# Laço  9.92641024737e-05  da varredura em N.
# Laço  0.000125682286164  da varredura em N.
# Laço  0.000159131414699  da varredura em N.
# Laço  0.000201482706251  da varredura em N.
# Laço  0.000255105385665  da varredura em N.
# Laço  0.000322999224133  da varredura em N.
# Laço  0.000408962353023  da varredura em N.
# [0.0016763709148604306, 4.8904256961953734e-05, 4.8904256961953734e-05, 1.1870132149297034e-05]

# %%
reg2 = lp.InvLaplace(sig2, 0) #0=cpmg/1=invrec
reg2.genX(1e-4,1e0,10) #Xi, Xf, N
reg2.genY([4.8904256961953734e-05, 4.8904256961953734e-05, 1.1870132149297034e-05], 0, 'nn0') #[N,G,C], 0=noTSVD/1=TSVD, '0'/'nn0'/'nnx'/'x'
#sim.plotData()
#reg2.plotData()
#plt.show()
#print 'Desvio quadrático médio:', lp.rmsDiff(sim.Y, reg2.Y) #utilizar 2 ou 3 algarismos significativos

plt.plot(sim.X,sim.Y)
plt.plot(reg2.X,reg2.Y)
plt.xlabel('inverse time [s]')
plt.ylabel('amplitude')
plt.xscale('log')
plt.grid(True)
plt.legend(['Dist. Simulada','Dist. TLI'],loc=0)
plt.text(0.002,0,'Desvio RMS: 0.0017')
plt.savefig('Sim_Comp_1e4_Mm_10pt.png',dpi=300)

# %%
# SNR = 1.000

sig3 = lp.NMRDecay(sim, 'cpmg') #'cpmg'/'invrec'
sig3.genX(1e-4,2,2000) #xi, xf, N
sig3.genY()
sig3.addGaussNoise(1e3)
#sig3.plotData()

plt.plot(sig3.x,sig3.yn)
plt.xlabel('direct time [s]')
plt.ylabel('amplitude with noise')
plt.grid(True)
plt.legend(['Dec. Simulado'],loc=0)
plt.savefig('Sim_Decay_1e3_Mm_10pt.png',dpi=300)

# %%
reg3 = lp.InvLaplace(sig3, 0) #0=cpmg/1=invrec
reg3.genX(1e-4,1e0,10) #Xi, Xf, N

Opt3 = FindOpt(1e-8,2,10,1e-8,2,10,1e-8,2,10,reg3)
print Opt3
# Out:
# Laço  1e-08  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.01289157423966388, 1e-08, 1e-08, 1e-08]
# Última otimização do ajuste grosso:  [0.01289007566451524, 1e-08, 1e-08, 8.362510309503733e-08]
# Última otimização do ajuste grosso:  [0.008373041474305927, 1e-08, 1e-08, 6.993157867655623e-07]
# Última otimização do ajuste grosso:  [0.007702582422629061, 1e-08, 1e-08, 5.848035476425729e-06]
# Última otimização do ajuste grosso:  [0.004531507138584118, 1e-08, 1e-08, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.004530473175127098, 1e-08, 8.362510309503733e-08, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.004521835578687283, 1e-08, 6.993157867655623e-07, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.004450240048424071, 1e-08, 5.848035476425729e-06, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.0039026874457015583, 1e-08, 4.8904256961953734e-05, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.0035001152185617484, 1e-08, 0.0004089623530229578, 1e-08]
# Última otimização do ajuste grosso:  [0.0034990816511311787, 1e-08, 0.0004089623530229578, 8.362510309503733e-08]
# Última otimização do ajuste grosso:  [0.0034913615208183543, 1e-08, 0.0004089623530229578, 6.993157867655623e-07]
# Última otimização do ajuste grosso:  [0.003490465353817464, 1e-08, 0.0004089623530229578, 5.848035476425729e-06]
# Laço  8.3625103095e-08  da varredura em Ns.
# Laço  6.99315786766e-07  da varredura em Ns.
# Laço  5.84803547643e-06  da varredura em Ns.
# Laço  4.8904256962e-05  da varredura em Ns.
# Laço  0.000408962353023  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.0031252232604419444, 0.0004089623530229578, 1e-08, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.003124698783261892, 0.0004089623530229578, 8.362510309503733e-08, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.0031203348041668067, 0.0004089623530229578, 6.993157867655623e-07, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.0030853887678702137, 0.0004089623530229578, 5.848035476425729e-06, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.0029100096227714436, 0.0004089623530229578, 4.8904256961953734e-05, 4.8904256961953734e-05]
# Laço  0.00341995189335  da varredura em Ns.
# Laço  0.0285993829662  da varredura em Ns.
# Laço  0.2391626349  da varredura em Ns.
# Laço  2.0  da varredura em Ns.
# Laço  0.000408962353023  da varredura em N.
# Última otimização do ajuste fino:  [0.002900702643974421, 0.0004089623530229578, 6.19196533790181e-05, 4.8904256961953734e-05]
# Laço  0.000517803739743  da varredura em N.
# Laço  0.000655612212004  da varredura em N.
# Laço  0.0008300970803  da varredura em N.
# Laço  0.00105101941377  da varredura em N.
# Laço  0.00133073809599  da varredura em N.
# Laço  0.00168490120821  da varredura em N.
# Laço  0.00213332141763  da varredura em N.
# Laço  0.00270108434177  da varredura em N.
# Laço  0.00341995189335  da varredura em N.
# [0.002900702643974421, 0.0004089623530229578, 6.19196533790181e-05, 4.8904256961953734e-05]

# %%
reg3 = lp.InvLaplace(sig3, 0) #0=cpmg/1=invrec
reg3.genX(1e-4,1e0,10) #Xi, Xf, N
reg3.genY([0.0004089623530229578, 6.19196533790181e-05, 4.8904256961953734e-05], 0, 'nn0') #[N,G,C], 0=noTSVD/1=TSVD, '0'/'nn0'/'nnx'/'x'
#sim.plotData()
#reg3.plotData()
#plt.show()
#print 'Desvio quadrático médio:', lp.rmsDiff(sim.Y, reg3.Y) #utilizar 2 ou 3 algarismos significativos

plt.plot(sim.X,sim.Y)
plt.plot(reg3.X,reg3.Y)
plt.xlabel('inverse time [s]')
plt.ylabel('amplitude')
plt.xscale('log')
plt.grid(True)
plt.legend(['Dist. Simulada','Dist. TLI'],loc=0)
plt.text(0.002,0,'Desvio RMS: 0.0029')
plt.savefig('Sim_Comp_1e3_Mm_10pt.png',dpi=300)

# %%
# SNR = 100

sig4 = lp.NMRDecay(sim, 'cpmg') #'cpmg'/'invrec'
sig4.genX(1e-4,2,2000) #xi, xf, N
sig4.genY()
sig4.addGaussNoise(1e2)
#sig4.plotData()

plt.plot(sig4.x,sig4.yn)
plt.xlabel('direct time [s]')
plt.ylabel('amplitude with noise')
plt.grid(True)
plt.legend(['Dec. Simulado'],loc=0)
plt.savefig('Sim_Decay_1e2_Mm_10pt.png',dpi=300)

# %%
reg4 = lp.InvLaplace(sig4, 0) #0=cpmg/1=invrec
reg4.genX(1e-4,1e0,10) #Xi, Xf, N

Opt4 = FindOpt(1e-8,2,10,1e-8,2,10,1e-8,2,10,reg4)
print Opt4
# Out:
# Laço  1e-08  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.03319804253693488, 1e-08, 1e-08, 1e-08]
# Última otimização do ajuste grosso:  [0.03319355000019277, 1e-08, 1e-08, 8.362510309503733e-08]
# Última otimização do ajuste grosso:  [0.033155994219628594, 1e-08, 1e-08, 6.993157867655623e-07]
# Última otimização do ajuste grosso:  [0.032842849582588166, 1e-08, 1e-08, 5.848035476425729e-06]
# Última otimização do ajuste grosso:  [0.030287866950864568, 1e-08, 1e-08, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.013695280473234053, 1e-08, 1e-08, 0.0004089623530229578]
# Última otimização do ajuste grosso:  [0.013694631977244963, 1e-08, 8.362510309503733e-08, 0.0004089623530229578]
# Última otimização do ajuste grosso:  [0.01368921075765761, 1e-08, 6.993157867655623e-07, 0.0004089623530229578]
# Última otimização do ajuste grosso:  [0.013644004267512463, 1e-08, 5.848035476425729e-06, 0.0004089623530229578]
# Última otimização do ajuste grosso:  [0.01327510725291395, 1e-08, 4.8904256961953734e-05, 0.0004089623530229578]
# Última otimização do ajuste grosso:  [0.0109274106576712, 1e-08, 0.0004089623530229578, 0.0004089623530229578]
# Laço  8.3625103095e-08  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.01092731466403308, 8.362510309503733e-08, 0.0004089623530229578, 0.0004089623530229578]
# Laço  6.99315786766e-07  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.01092651214047074, 6.993157867655623e-07, 0.0004089623530229578, 0.0004089623530229578]
# Laço  5.84803547643e-06  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.010919816512260594, 5.848035476425729e-06, 0.0004089623530229578, 0.0004089623530229578]
# Laço  4.8904256962e-05  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.010864910526431487, 4.8904256961953734e-05, 0.0004089623530229578, 0.0004089623530229578]
# Laço  0.000408962353023  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.010483471076615939, 0.0004089623530229578, 0.0004089623530229578, 0.0004089623530229578]
# Laço  0.00341995189335  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.010475797286910903, 0.00341995189335339, 1e-08, 0.0004089623530229578]
# Laço  0.0285993829662  da varredura em Ns.
# Laço  0.2391626349  da varredura em Ns.
# Laço  2.0  da varredura em Ns.
# Laço  0.00341995189335  da varredura em N.
# Laço  0.0043301391119  da varredura em N.
# Laço  0.00548256388192  da varredura em N.
# Laço  0.0069416953919  da varredura em N.
# Laço  0.00878916068315  da varredura em N.
# Laço  0.011128311047  da varredura em N.
# Laço  0.0140900037242  da varredura em N.
# Laço  0.0178399223485  da varredura em N.
# Laço  0.0225878456549  da varredura em N.
# Laço  0.0285993829662  da varredura em N.
# [0.010475797286910903, 0.00341995189335339, 1e-08, 0.0004089623530229578]

# %%
reg4 = lp.InvLaplace(sig4, 0) #0=cpmg/1=invrec
reg4.genX(1e-4,1e0,10) #Xi, Xf, N
reg4.genY([0.00341995189335339, 1e-08, 0.0004089623530229578], 0, 'nn0') #[N,G,C], 0=noTSVD/1=TSVD, '0'/'nn0'/'nnx'/'x'
#sim.plotData()
#reg4.plotData()
#plt.show()
#print 'Desvio quadrático médio:', lp.rmsDiff(sim.Y, reg4.Y) #utilizar 2 ou 3 algarismos significativos

plt.plot(sim.X,sim.Y)
plt.plot(reg4.X,reg4.Y)
plt.xlabel('inverse time [s]')
plt.ylabel('amplitude')
plt.xscale('log')
plt.grid(True)
plt.legend(['Dist. Simulada','Dist. TLI'],loc=0)
plt.text(0.002,0,'Desvio RMS: 0.0105')
plt.savefig('Sim_Comp_1e2_Mm_10pt.png',dpi=300)

# %%
# SNR = 10

sig5 = lp.NMRDecay(sim, 'cpmg') #'cpmg'/'invrec'
sig5.genX(1e-4,2,2000) #xi, xf, N
sig5.genY()
sig5.addGaussNoise(10)
#sig5.plotData()

plt.plot(sig5.x,sig5.yn)
plt.xlabel('direct time [s]')
plt.ylabel('amplitude with noise')
plt.grid(True)
plt.legend(['Dec. Simulado'],loc=0)
plt.savefig('Sim_Decay_1e1_Mm_10pt.png',dpi=300)

# %%
reg5 = lp.InvLaplace(sig5, 0) #0=cpmg/1=invrec
reg5.genX(1e-4,1e0,10) #Xi, Xf, N

Opt5 = FindOpt(1e-8,2,10,1e-8,2,10,1e-8,2,10,reg5)
print Opt5
# Out:
# Laço  1e-08  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.10855226033821735, 1e-08, 1e-08, 1e-08]
# Última otimização do ajuste grosso:  [0.10854605338848297, 1e-08, 1e-08, 8.362510309503733e-08]
# Última otimização do ajuste grosso:  [0.10849416141579106, 1e-08, 1e-08, 6.993157867655623e-07]
# Última otimização do ajuste grosso:  [0.10806117102516935, 1e-08, 1e-08, 5.848035476425729e-06]
# Última otimização do ajuste grosso:  [0.10450603447992281, 1e-08, 1e-08, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.07976645447203899, 1e-08, 1e-08, 0.0004089623530229578]
# Última otimização do ajuste grosso:  [0.02147539842402429, 1e-08, 1e-08, 0.00341995189335339]
# Laço  8.3625103095e-08  da varredura em Ns.
# Laço  6.99315786766e-07  da varredura em Ns.
# Laço  5.84803547643e-06  da varredura em Ns.
# Laço  4.8904256962e-05  da varredura em Ns.
# Laço  0.000408962353023  da varredura em Ns.
# Laço  0.00341995189335  da varredura em Ns.
# Laço  0.0285993829662  da varredura em Ns.
# Última otimização do ajuste grosso:  [0.015613238534181508, 0.028599382966174536, 1e-08, 1e-08]
# Última otimização do ajuste grosso:  [0.015612734034055666, 0.028599382966174536, 1e-08, 8.362510309503733e-08]
# Última otimização do ajuste grosso:  [0.015608524110373728, 0.028599382966174536, 1e-08, 6.993157867655623e-07]
# Última otimização do ajuste grosso:  [0.01557394555048495, 0.028599382966174536, 1e-08, 5.848035476425729e-06]
# Última otimização do ajuste grosso:  [0.01532861719453921, 0.028599382966174536, 1e-08, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.015328515921047305, 0.028599382966174536, 8.362510309503733e-08, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.015327669737176345, 0.028599382966174536, 6.993157867655623e-07, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.01532064379549069, 0.028599382966174536, 5.848035476425729e-06, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.015265401748676917, 0.028599382966174536, 4.8904256961953734e-05, 4.8904256961953734e-05]
# Última otimização do ajuste grosso:  [0.015094594176176541, 0.028599382966174536, 0.0004089623530229578, 1e-08]
# Última otimização do ajuste grosso:  [0.01509444721677296, 0.028599382966174536, 0.0004089623530229578, 8.362510309503733e-08]
# Última otimização do ajuste grosso:  [0.015093226913599713, 0.028599382966174536, 0.0004089623530229578, 6.993157867655623e-07]
# Última otimização do ajuste grosso:  [0.015083625835830153, 0.028599382966174536, 0.0004089623530229578, 5.848035476425729e-06]
# Última otimização do ajuste grosso:  [0.015044962865279864, 0.028599382966174536, 0.0004089623530229578, 4.8904256961953734e-05]
# Laço  0.2391626349  da varredura em Ns.
# Laço  2.0  da varredura em Ns.
# Laço  0.0285993829662  da varredura em N.
# Laço  0.0362108329648  da varredura em N.
# Laço  0.0458479969851  da varredura em N.
# Laço  0.0580499992802  da varredura em N.
# Laço  0.0734994468248  da varredura em N.
# Laço  0.0930606158576  da varredura em N.
# Laço  0.117827801404  da varredura em N.
# Laço  0.14918653456  da varredura em N.
# Laço  0.188891092159  da varredura em N.
# Laço  0.2391626349  da varredura em N.
# [0.015044962865279864, 0.028599382966174536, 0.0004089623530229578, 4.8904256961953734e-05]

# %%
reg5 = lp.InvLaplace(sig5, 0) #0=cpmg/1=invrec
reg5.genX(1e-4,1e0,10) #Xi, Xf, N
reg5.genY([0.028599382966174536, 0.0004089623530229578, 4.8904256961953734e-05], 0, 'nn0') #[N,G,C], 0=noTSVD/1=TSVD, '0'/'nn0'/'nnx'/'x'
#sim.plotData()
#reg5.plotData()
#plt.show()
#print 'Desvio quadrático médio:', lp.rmsDiff(sim.Y, reg5.Y) #utilizar 2 ou 3 algarismos significativos

plt.plot(sim.X,sim.Y)
plt.plot(reg5.X,reg5.Y)
plt.xlabel('inverse time [s]')
plt.ylabel('amplitude')
plt.xscale('log')
plt.grid(True)
plt.legend(['Dist. Simulada','Dist. TLI'],loc=0)
plt.text(0.002,0,'Desvio RMS: 0.0150')
plt.savefig('Sim_Comp_1e1_Mm_10pt.png',dpi=300)
